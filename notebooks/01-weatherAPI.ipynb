# %%
import requests
import pandas as pd

# %%
params = {
    "date": "2010-01-01",
    "dwd_station_id": "00662",
    "last_date": "2024-07-30"
}

url = "https://api.brightsky.dev/weather"

# %%
response = requests.get(url, params=params)

# %%
response.json()
# Out:
# {'weather': [{'timestamp': '2010-01-01T00:00:00+00:00',
#    'source_id': 6905,
#    'precipitation': 0.0,
#    'pressure_msl': 997.0,
#    'sunshine': None,
#    'temperature': -1.8,
#    'wind_direction': 60,
#    'wind_speed': 18.7,
#    'cloud_cover': 100,
#    'dew_point': -3.4,
#    'relative_humidity': 89,
#    'visibility': 9000,
#    'wind_gust_direction': 80,
#    'wind_gust_speed': 24.8,
#    'condition': 'dry',
#    'precipitation_probability': None,
#    'precipitation_probability_6h': None,
#    'solar': None,
#    'fallback_source_ids': {},
#    'icon': 'cloudy'},
#   {'timestamp': '2010-01-01T01:00:00+00:00',
#    'source_id': 6905,
#    'precipitation': 0.0,
#    'pressure_msl': 996.6,
#    'sunshine': None,
#    'temperature': -1.8,
#    'wind_direction': 70,
#    'wind_speed': 16.9,
#    'cloud_cover': 100,
#    'dew_point': -3.5,
#    'relative_humidity': 88,
#    'visibility': 12000,
#    'wind_gust_direction': 50,
#    'wind_gust_speed': 28.8,
# ...

# %%
pd.DataFrame(response.json()["weather"])
# Out:
#                         timestamp  source_id  precipitation  pressure_msl  \
# 0       2010-01-01T00:00:00+00:00       6905            0.0         997.0
# 1       2010-01-01T01:00:00+00:00       6905            0.0         996.6
# 2       2010-01-01T02:00:00+00:00       6905            0.0         996.7
# 3       2010-01-01T03:00:00+00:00       6905            0.0         996.5
# 4       2010-01-01T04:00:00+00:00       6905            0.2         996.5
# ...                           ...        ...            ...           ...
# 127772  2024-07-29T20:00:00+00:00       6905            0.0        1022.1
# 127773  2024-07-29T21:00:00+00:00       6905            0.0        1022.1
# 127774  2024-07-29T22:00:00+00:00       6905            0.0        1021.9
# 127775  2024-07-29T23:00:00+00:00       6905            0.0        1021.8
# 127776  2024-07-30T00:00:00+00:00      56820            0.0        1021.4
#
#         sunshine  temperature  wind_direction  wind_speed  cloud_cover  \
# ...

# %%
def get_climate_from_api():
    params = {
        "date": "2010-01-01",
        "dwd_station_id": "00662",
        "last_date": "2024-07-30"
    }

    url = "https://api.brightsky.dev/weather"
    response = requests.get(url, params=params)

    climate_data = pd.DataFrame(response.json()["weather"])
    climate_data.to_csv(utils.get_)

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d")
# Out:
# '2024-07-30'
