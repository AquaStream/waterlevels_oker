# %%
import seaborn as sns
import matplotlib.pyplot as plt
from waterlevels_oker.data import preprocess_ohrum_data

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
plt.style.use("default")

# %%
ohrum = preprocess_ohrum_data()

# %%
ohrum
# Out:
#                      Waterlevel relative [cm]
# 2005-01-01 01:00:00                     120.0
# 2005-01-01 02:00:00                     120.0
# 2005-01-01 03:00:00                     120.0
# 2005-01-01 04:00:00                     121.0
# 2005-01-01 05:00:00                     121.0
# ...                                       ...
# 2024-07-28 19:00:00                     168.0
# 2024-07-28 20:00:00                     166.0
# 2024-07-28 21:00:00                     164.0
# 2024-07-28 22:00:00                     161.0
# 2024-07-28 23:00:00                     160.0
#
# [171575 rows x 1 columns]

# %%
ohrum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 171575 entries, 2005-01-01 01:00:00 to 2024-07-28 23:00:00
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Waterlevel relative [cm]  171575 non-null  float64
# dtypes: float64(1)
# memory usage: 6.6 MB

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.lineplot(ohrum["Waterlevel relative [cm]"], ax=ax);

# %%
fig, ax = plt.subplots(figsize=(12,4))
for year in range(2005, 2025):
    sns.lineplot(x=ohrum.loc[str(year)].index.dayofyear, y=ohrum.loc[str(year),"Waterlevel relative [cm]"], ax=ax)
ax.set_xlabel("")
ax.tick_params(
    axis='x',
    labelbottom=False)
ax.set_title("2005 – 2024")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for year in range(2005, 2010):
    sns.lineplot(x=ohrum.loc[str(year)].index.dayofyear, y=ohrum.loc[str(year),"Waterlevel relative [cm]"], ax=ax)
ax.set_xlabel("")
ax.tick_params(
    axis='x',
    labelbottom=False)
ax.set_title("2005 – 2009")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for year in range(2010, 2015):
    sns.lineplot(x=ohrum.loc[str(year)].index.dayofyear, y=ohrum.loc[str(year),"Waterlevel relative [cm]"], ax=ax)
ax.set_xlabel("")
ax.tick_params(
    axis='x',
    labelbottom=False)
ax.set_title("2010 – 2014")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for year in range(2015, 2020):
    sns.lineplot(x=ohrum.loc[str(year)].index.dayofyear, y=ohrum.loc[str(year),"Waterlevel relative [cm]"], ax=ax)
ax.set_xlabel("")
ax.tick_params(
    axis='x',
    labelbottom=False)
ax.set_title("2015 – 2019")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
for year in range(2020, 2025):
    sns.lineplot(x=ohrum.loc[str(year)].index.dayofyear, y=ohrum.loc[str(year),"Waterlevel relative [cm]"], ax=ax)
ax.set_xlabel("")
ax.tick_params(
    axis='x',
    labelbottom=False)
ax.set_title("2020 – 2024")
plt.show()
